# %%
import anndata
import pandas as pd
import numpy as np
from pandas import *
from sklearn import preprocessing
import random
import pickle

# %%
merge = anndata.read_h5ad("./sample/merge_sct.h5ad")
min_max_scaler = preprocessing.MinMaxScaler()
df = pd.DataFrame(merge.X)
df = df.transpose()
df = min_max_scaler.fit_transform(df)
df = pd.DataFrame(df)
df = df.transpose()
df.index = merge.obs.index.values
df.columns = merge.var.index.values
l = pd.read_csv("./sample/sample_barcode.csv")["barcode"].tolist()
sample = df.loc[l]
sample
# Out:
#                      ENSG00000132465  ENSG00000211592  ENSG00000211677  \
# TGCGCAGCATCAGTAC-19         0.503419         1.000000         0.441148
# AAGGTTCCAACCGCCA-28         0.342261         0.299407         1.000000
# CTACCCACAGATGGGT-15         0.330620         0.220530         0.284177
# ATAAGAGCACTAGTAC-26         0.330759         0.190778         1.000000
# TTATGCTCAATGCCAT-2          0.266352         0.148202         0.241751
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10         1.000000         1.000000         0.288402
# AGTCTTTCAGCTGTTA-28         0.233909         0.093009         0.203745
# TTCTTAGTCTGCCCTA-17         0.276216         0.181637         0.228042
# GGACATTAGACGCTTT-16         0.330867         0.194152         0.278867
# GGGTCTGAGACCTTTG-44         0.351308         0.188441         0.290926
#
#                      ENSG00000211895  ENSG00000163220  ENSG00000143546  \
# TGCGCAGCATCAGTAC-19         0.707511         0.057549         0.110535
# AAGGTTCCAACCGCCA-28         0.348240         0.065036         0.110486
# CTACCCACAGATGGGT-15         0.403575         0.142602         0.193052
# ATAAGAGCACTAGTAC-26         0.397537         0.052791         0.101537
# TTATGCTCAATGCCAT-2          0.284668         0.000000         0.060350
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.985170         0.086249         0.108075
# AGTCTTTCAGCTGTTA-28         0.260704         0.000000         0.039065
# TTCTTAGTCTGCCCTA-17         0.297762         0.000000         0.117286
# GGACATTAGACGCTTT-16         0.333137         0.055958         0.109943
# GGGTCTGAGACCTTTG-44         0.349033         0.053021         0.117020
#
#                      ENSG00000211679  ENSG00000115523  ENSG00000211899  \
# TGCGCAGCATCAGTAC-19         0.310952         0.000000         0.264991
# AAGGTTCCAACCGCCA-28         1.000000         0.000000         1.000000
# CTACCCACAGATGGGT-15         0.310711         0.000000         0.255585
# ATAAGAGCACTAGTAC-26         1.000000         0.000000         1.000000
# TTATGCTCAATGCCAT-2          0.258447         1.000000         0.197461
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.305566         0.000000         0.256641
# AGTCTTTCAGCTGTTA-28         0.220085         0.456062         0.141617
# TTCTTAGTCTGCCCTA-17         0.248837         0.766531         0.193832
# GGACATTAGACGCTTT-16         0.308209         0.000000         0.246443
# GGGTCTGAGACCTTTG-44         0.316974         0.000000         0.292978
#
#                      ENSG00000107317  ...  ENSG00000181163  ENSG00000130429  \
# TGCGCAGCATCAGTAC-19         0.317677  ...         0.343373         0.341747
# AAGGTTCCAACCGCCA-28         0.317841  ...         0.353809         0.319618
# CTACCCACAGATGGGT-15         0.324970  ...         0.331830         0.522567
# ATAAGAGCACTAGTAC-26         0.307017  ...         0.397787         0.366803
# TTATGCTCAATGCCAT-2          0.392465  ...         0.310102         0.323897
# ...                              ...  ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.318316  ...         0.333110         0.341481
# AGTCTTTCAGCTGTTA-28         0.214594  ...         0.288970         0.261797
# TTCTTAGTCTGCCCTA-17         0.851122  ...         0.276545         0.279196
# GGACATTAGACGCTTT-16         0.315693  ...         0.432655         0.352205
# GGGTCTGAGACCTTTG-44         0.321091  ...         0.466369         0.389215
#
#                      ENSG00000213719  ENSG00000133872  ENSG00000108107  \
# TGCGCAGCATCAGTAC-19         0.352115         0.319445         0.311611
# AAGGTTCCAACCGCCA-28         0.320226         0.322888         0.330256
# CTACCCACAGATGGGT-15         0.392866         0.333221         0.360797
# ATAAGAGCACTAGTAC-26         0.315228         0.341888         0.381798
# TTATGCTCAATGCCAT-2          0.409631         0.294468         0.232291
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.404263         0.360291         0.390947
# AGTCTTTCAGCTGTTA-28         0.336115         0.243139         0.260755
# TTCTTAGTCTGCCCTA-17         0.295343         0.312750         0.234167
# GGACATTAGACGCTTT-16         0.319105         0.456419         0.389160
# GGGTCTGAGACCTTTG-44         0.462982         0.370946         0.435094
#
#                      ENSG00000198727  ENSG00000241343  ENSG00000255325  \
# TGCGCAGCATCAGTAC-19         0.370466         0.393582         0.369410
# AAGGTTCCAACCGCCA-28         0.394104         0.301186         0.370222
# CTACCCACAGATGGGT-15         0.356063         0.378431         0.377776
# ATAAGAGCACTAGTAC-26         0.328277         0.409144         0.361679
# TTATGCTCAATGCCAT-2          0.365432         0.348559         0.322036
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.369140         0.365670         0.371893
# AGTCTTTCAGCTGTTA-28         0.217314         0.268835         0.275273
# TTCTTAGTCTGCCCTA-17         0.442885         0.256645         0.314515
# GGACATTAGACGCTTT-16         0.342242         0.421071         0.370782
# GGGTCTGAGACCTTTG-44         0.380765         0.372035         0.379474
#
#                      ENSG00000146278  ENSG00000134201
# TGCGCAGCATCAGTAC-19         0.328479         0.369108
# AAGGTTCCAACCGCCA-28         0.393368         0.369921
# CTACCCACAGATGGGT-15         0.375635         0.377466
# ATAAGAGCACTAGTAC-26         0.352026         0.361374
# TTATGCTCAATGCCAT-2          0.378800         0.321716
# ...                              ...              ...
# TCTTTCCAGTGAAGAG-10         0.367928         0.371590
# AGTCTTTCAGCTGTTA-28         0.389680         0.274930
# TTCTTAGTCTGCCCTA-17         0.433568         0.314194
# GGACATTAGACGCTTT-16         0.360090         0.370483
# GGGTCTGAGACCTTTG-44         0.339401         0.401463
#
# [10229 rows x 2722 columns]

# %%
#Fill zero when genes of the pretrained model are not included in the sample dataset.
gene_list = pd.read_csv("./pretrained/pretrained_genes.csv", index_col=0).index.tolist()
genes = sample.columns.values.tolist()
excluded_genes = list(set(gene_list) - set(genes)) 
blank_datarame = pd.DataFrame(np.zeros((len(sample.index.tolist()), len(excluded_genes))))
blank_datarame.index = sample.index.tolist()
blank_datarame.columns = excluded_genes
sample = pd.concat([sample, blank_datarame], axis=1)
sample = sample[gene_list]
sample
# Out:
#                      ENSG00000188290  ENSG00000187608  ENSG00000186891  \
# TGCGCAGCATCAGTAC-19         0.353187         0.313630         0.350192
# AAGGTTCCAACCGCCA-28         0.353290         0.327589         0.359320
# CTACCCACAGATGGGT-15         0.365497         0.323656         0.357084
# ATAAGAGCACTAGTAC-26         0.342623         0.329513         0.344185
# TTATGCTCAATGCCAT-2          0.353192         0.416368         0.593178
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.353038         0.398360         0.343756
# AGTCTTTCAGCTGTTA-28         0.257389         0.348193         0.269382
# TTCTTAGTCTGCCCTA-17         0.273181         0.325482         0.332640
# GGACATTAGACGCTTT-16         0.362802         0.324918         0.354029
# GGGTCTGAGACCTTTG-44         0.363679         0.364201         0.366869
#
#                      ENSG00000186827  ENSG00000162576  ENSG00000197530  \
# TGCGCAGCATCAGTAC-19         0.344606         0.366615         0.352591
# AAGGTTCCAACCGCCA-28         0.355221         0.367358         0.464297
# CTACCCACAGATGGGT-15         0.359273         0.374747         0.351537
# ATAAGAGCACTAGTAC-26         0.347491         0.358788         0.355232
# TTATGCTCAATGCCAT-2          0.297091         0.319018         0.411842
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.348181         0.369026         0.353432
# AGTCTTTCAGCTGTTA-28         0.276450         0.272219         0.292961
# TTCTTAGTCTGCCCTA-17         0.296857         0.311561         0.321552
# GGACATTAGACGCTTT-16         0.358053         0.367974         0.448941
# GGGTCTGAGACCTTTG-44         0.372878         0.381570         0.369687
#
#                      ENSG00000189409  ENSG00000149527  ENSG00000235169  \
# TGCGCAGCATCAGTAC-19         0.356347         0.372205         0.362515
# AAGGTTCCAACCGCCA-28         0.358002         0.367692         0.371730
# CTACCCACAGATGGGT-15         0.366178         0.371153         0.375267
# ATAAGAGCACTAGTAC-26         0.349362         0.366934         0.355117
# TTATGCTCAATGCCAT-2          0.326858         0.343122         0.315107
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.354453         0.385621         0.380147
# AGTCTTTCAGCTGTTA-28         0.736439         0.292936         0.280925
# TTCTTAGTCTGCCCTA-17         0.282560         0.312509         0.307776
# GGACATTAGACGCTTT-16         0.359104         0.347200         0.363511
# GGGTCTGAGACCTTTG-44         0.376128         0.383919         0.441198
#
#                      ENSG00000158292  ...  ENSG00000282651  ENSG00000211972  \
# TGCGCAGCATCAGTAC-19         0.365415  ...              0.0              0.0
# AAGGTTCCAACCGCCA-28         0.376264  ...              0.0              0.0
# CTACCCACAGATGGGT-15         0.373464  ...              0.0              0.0
# ATAAGAGCACTAGTAC-26         0.366418  ...              0.0              0.0
# TTATGCTCAATGCCAT-2          0.337012  ...              0.0              0.0
# ...                              ...  ...              ...              ...
# TCTTTCCAGTGAAGAG-10         0.367765  ...              0.0              0.0
# AGTCTTTCAGCTGTTA-28         0.270914  ...              0.0              0.0
# TTCTTAGTCTGCCCTA-17         0.337538  ...              0.0              0.0
# GGACATTAGACGCTTT-16         0.366720  ...              0.0              0.0
# GGGTCTGAGACCTTTG-44         0.375102  ...              0.0              0.0
#
#                      ENSG00000204866  ENSG00000253998  ENSG00000147206  \
# TGCGCAGCATCAGTAC-19              0.0              0.0              0.0
# AAGGTTCCAACCGCCA-28              0.0              0.0              0.0
# CTACCCACAGATGGGT-15              0.0              0.0              0.0
# ATAAGAGCACTAGTAC-26              0.0              0.0              0.0
# TTATGCTCAATGCCAT-2               0.0              0.0              0.0
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10              0.0              0.0              0.0
# AGTCTTTCAGCTGTTA-28              0.0              0.0              0.0
# TTCTTAGTCTGCCCTA-17              0.0              0.0              0.0
# GGACATTAGACGCTTT-16              0.0              0.0              0.0
# GGGTCTGAGACCTTTG-44              0.0              0.0              0.0
#
#                      ENSG00000231475  ENSG00000211976  ENSG00000223350  \
# TGCGCAGCATCAGTAC-19              0.0              0.0              0.0
# AAGGTTCCAACCGCCA-28              0.0              0.0              0.0
# CTACCCACAGATGGGT-15              0.0              0.0              0.0
# ATAAGAGCACTAGTAC-26              0.0              0.0              0.0
# TTATGCTCAATGCCAT-2               0.0              0.0              0.0
# ...                              ...              ...              ...
# TCTTTCCAGTGAAGAG-10              0.0              0.0              0.0
# AGTCTTTCAGCTGTTA-28              0.0              0.0              0.0
# TTCTTAGTCTGCCCTA-17              0.0              0.0              0.0
# GGACATTAGACGCTTT-16              0.0              0.0              0.0
# GGGTCTGAGACCTTTG-44              0.0              0.0              0.0
#
#                      ENSG00000241294  ENSG00000211951
# TGCGCAGCATCAGTAC-19              0.0              0.0
# AAGGTTCCAACCGCCA-28              0.0              0.0
# CTACCCACAGATGGGT-15              0.0              0.0
# ATAAGAGCACTAGTAC-26              0.0              0.0
# TTATGCTCAATGCCAT-2               0.0              0.0
# ...                              ...              ...
# TCTTTCCAGTGAAGAG-10              0.0              0.0
# AGTCTTTCAGCTGTTA-28              0.0              0.0
# TTCTTAGTCTGCCCTA-17              0.0              0.0
# GGACATTAGACGCTTT-16              0.0              0.0
# GGGTCTGAGACCTTTG-44              0.0              0.0
#
# [10229 rows x 3000 columns]

# %%
#Use the trained image transormer to tansform the sample dataset
file = open("./pretrained/img_transformer_pre.obj",'rb')
it = pickle.load(file)
file.close()
path = '/Usersdata/shangru/docker/sample/sample_query.npy'
query_img = (it.transform(sample)*255).astype(np.uint8)
np.save(path, query_img)

# %%
from torchvision import transforms
import torch
from torch import nn
import torch.optim as optim
import argparse
import torch.optim.lr_scheduler as lr_scheduler 
from efficientnet_pytorch import EfficientNet
from torch.utils.data import Dataset
import os
import numpy as np
import pandas as pd
from PIL import Image
from sklearn import preprocessing
import time
import matplotlib.pyplot as plt
import pickle
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics import accuracy_score
import warnings
warnings.simplefilter('ignore')
class MyTestSet(Dataset):
    def __init__(self, img):
        self.img = np.load(img)
        self.transforms = transforms.Compose([transforms.ToTensor(), ])
    def __getitem__(self, index):
        img = self.img[index, :, :, :]
        img = np.squeeze(img)
        img = Image.fromarray(np.uint8(img))
        img = self.transforms(img)
        return img
    def __len__(self):
        return self.img.shape[0]

test = MyTestSet("/Usersdata/shangru/docker/sample/sample_query.npy")
test_loader = torch.utils.data.DataLoader(test, batch_size=128, shuffle=False)

os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'
mod =EfficientNet.from_pretrained('efficientnet-b3', num_classes=31)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.device_count() > 1:
    mod = nn.DataParallel(mod)

torch.cuda.is_available()
torch.cuda.device_count()
torch.cuda.current_device()
torch.cuda.get_device_name()

mod.to(device)
mod = mod.to(device)
#Use pretrained model to predict cell types on the sample query dataset
mod.load_state_dict(torch.load(("./pretrained/checkpoint_model_pre.pth")))
mod.eval()

out = []
for i, data in enumerate(test_loader):
    query = data
    query = query.to(device)
    pred= mod(query)
    _, predicted = torch.max(pred.data, 1)
    out.append(predicted)

pred = torch.cat(out, dim=0)
pr = pred.cpu().numpy()
# Out:
# Loaded pretrained weights for efficientnet-b3

# %%
real_label = pd.read_csv("./sample/real_sample_labels.csv", index_col=0)
real_label.value_counts()
# Out:
# celltype
# NK                   4390
# B naive              1178
# CD8 TEM              1173
# CD14 Mono            1084
# CD8 Naive             621
# CD16 Mono             536
# B memory              396
# CD4 TCM               185
# CD4 Naive             162
# cDC2                  136
# Plasmablast           130
# gdT                    74
# HSPC                   41
# pDC                    40
# B intermediate         29
# NK Proliferating       15
# Treg                   11
# MAIT                   10
# NK_CD56bright           7
# Platelet                7
# CD8 TCM                 1
# CD4 TEM                 1
# dnT                     1
# CD4 Proliferating       1
# dtype: int64

# %%
file = open("./pretrained/label_encoder_pre.obj",'rb')
le = pickle.load(file)
file.close()
pred_label = le.inverse_transform(pr)
pred_label = pd.DataFrame(pred_label)
pred_label.value_counts()
# Out:
# NK                   4237
# CD14 Mono            1173
# CD8 TEM              1128
# B naive               994
# CD16 Mono             509
# CD8 Naive             492
# B memory              396
# CD4 TCM               270
# B intermediate        213
# Plasmablast           131
# CD4 Naive             109
# CD8 TCM               107
# cDC2                  104
# gdT                    95
# NK_CD56bright          74
# HSPC                   41
# pDC                    40
# CD4 TEM                33
# NK Proliferating       31
# MAIT                   27
# Platelet               10
# Treg                    6
# CD4 CTL                 5
# Doublet                 3
# CD4 Proliferating       1
# dtype: int64

# %%
ls = list(set(pd.unique(pred_label[0]).tolist()) | set(pd.unique(real_label["celltype"]).tolist()))
acc = accuracy_score(pred_label,real_label)

le2 = preprocessing.LabelEncoder()
le2.fit(ls)
pred_label_2 = le2.transform(pred_label[0])
real_label_2 = le2.transform(real_label["celltype"])
ari = adjusted_rand_score(real_label_2, pred_label_2)

print("Accuray: %.03f, ARI = %.03f" % (acc, ari))
# Out:
# Accuray: 0.936, ARI = 0.938
